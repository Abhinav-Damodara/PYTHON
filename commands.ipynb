# %%
# "ls" command is used to display al the folders in that directory or folder
# "cd" is used to change the directory from one flder to another folder
# "cd (followed by the file name)" This oes to the corresponding folder.


# shell command:
# python (followed by the file name)
# cd .. = this takes you into the previous directory
# cat 

# when you are operating programs in text files : save the format with .txt extention 
# echo command is used to type
