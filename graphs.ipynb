# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinavGitam/Python/blob/main/graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 60, 100, 190, 230])
ypoints = np.array([0, 100, 162, 120, 200])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Math", "Phy", "English", "CSEN"])
y = np.array([95, 75, 89, 99])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([25, 25, 25, 25])
a = ["abhi", "vedesh", "abhihith", "puppy"]

plt.pie(y,labels = a)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(160, 10, 250)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()
